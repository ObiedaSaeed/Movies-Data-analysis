# %%
import pandas as pd
import numpy as np
import csv

# %%
df=pd.read_csv(r'C:\Users\Obieda Saeed\Desktop\J data analysis assignment\movie1.csv')

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.columns = df.columns.str.upper()

# %%
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df = df.fillna(0)

# %%
df = df.drop_duplicates('MOVIE_TITLE')

# %%
df.head(10)
# Out:
#                                    MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                     Avatar?ÿ                     723
# 1   Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                    Spectre?ÿ                     602
# 3                      The Dark Knight Rises?ÿ                     813
# 4                                John Carter?ÿ                     462
# 5                               Spider-Man 3?ÿ                     392
# 6                                    Tangled?ÿ                     324
# 7                    Avengers: Age of Ultron?ÿ                     635
# 9     Harry Potter and the Half-Blood Prince?ÿ                     375
# 10        Batman v Superman: Dawn of Justice?ÿ                     673
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0      178.0                      10                     855
# 1        0.0                     563                    1000
# ...

# %%
df.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS         int64
# DURATION                     float64
# DIRECTOR_FACEBOOK_LIKES       object
# ACTOR_3_FACEBOOK_LIKES         int64
# ACTOR_1_FACEBOOK_LIKES         int64
# GROSS                          int64
# NUM_VOTED_USERS              float64
# CAST_TOTAL_FACEBOOK_LIKES    float64
# FACENUMBER_IN_POSTER         float64
# NUM_USER_FOR_REVIEWS           int64
# BUDGET                         int64
# TITLE_YEAR                     int64
# ACTOR_2_FACEBOOK_LIKES       float64
# IMDB_SCORE                   float64
# TITLE_YEAR.1                 float64
# dtype: object

# %%
import re

# %%
MOVIE_TITLE = df.MOVIE_TITLE

# %%
df.MOVIE_TITLE = MOVIE_TITLE.str[:-2]

# %%
df
# Out:
#                                    MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# 12                           Quantum of Solace                     403
# ...

# %%
round(df['DURATION'].mean())
# Out:
# 144

# %%
DU = df.DURATION.replace({117:round(df['DURATION'].mean())})

# %%
df.DURATION = DU

# %%
df["DIRECTOR_FACEBOOK_LIKES"]=df["DIRECTOR_FACEBOOK_LIKES"].replace({'"475"':475})

# %%
df.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302     144.0
# 2                                   Spectre                     602     148.0
# 3                     The Dark Knight Rises                     813     144.0
# 4                               John Carter                     462     132.0
#
#    DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                       10                     855                    1000
# 1                      563                    1000                   40000
# 2                       20                     161                   11000
# 3                    22000                   23000                   27000
# 4                      475                     530                     640
#
# ...

# %%
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     0
# DIRECTOR_FACEBOOK_LIKES      0
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              0
# CAST_TOTAL_FACEBOOK_LIKES    0
# FACENUMBER_IN_POSTER         0
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       0
# IMDB_SCORE                   0
# TITLE_YEAR.1                 0
# dtype: int64

# %%
df[['DURATION', 'DIRECTOR_FACEBOOK_LIKES','NUM_VOTED_USERS','CAST_TOTAL_FACEBOOK_LIKES','FACENUMBER_IN_POSTER','ACTOR_2_FACEBOOK_LIKES']] = df[['DURATION', 'DIRECTOR_FACEBOOK_LIKES','NUM_VOTED_USERS','CAST_TOTAL_FACEBOOK_LIKES','FACENUMBER_IN_POSTER','ACTOR_2_FACEBOOK_LIKES']].astype('int')

# %%
df.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS         int64
# DURATION                       int32
# DIRECTOR_FACEBOOK_LIKES        int32
# ACTOR_3_FACEBOOK_LIKES         int64
# ACTOR_1_FACEBOOK_LIKES         int64
# GROSS                          int64
# NUM_VOTED_USERS                int32
# CAST_TOTAL_FACEBOOK_LIKES      int32
# FACENUMBER_IN_POSTER           int32
# NUM_USER_FOR_REVIEWS           int64
# BUDGET                         int64
# TITLE_YEAR                     int64
# ACTOR_2_FACEBOOK_LIKES         int32
# IMDB_SCORE                   float64
# TITLE_YEAR.1                  object
# dtype: object

# %%
df["TITLE_YEAR.1"] = df["TITLE_YEAR.1"].replace({0:"NOT APPLICABLE"})

# %%
df['TITLE_YEAR']= df['TITLE_YEAR'].astype('str')

# %%
df.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS         int64
# DURATION                       int32
# DIRECTOR_FACEBOOK_LIKES        int32
# ACTOR_3_FACEBOOK_LIKES         int64
# ACTOR_1_FACEBOOK_LIKES         int64
# GROSS                          int64
# NUM_VOTED_USERS                int32
# CAST_TOTAL_FACEBOOK_LIKES      int32
# FACENUMBER_IN_POSTER           int32
# NUM_USER_FOR_REVIEWS           int64
# BUDGET                         int64
# TITLE_YEAR                    object
# ACTOR_2_FACEBOOK_LIKES         int32
# IMDB_SCORE                   float64
# TITLE_YEAR.1                  object
# dtype: object

# %%
df.shape
# Out:
# (13, 16)

# %%
df.to_csv('moive_cleaned.csv', encoding='utf-8', index=False)
